# %%
from pybaseball.plotting import plot_strike_zone
from pybaseball import statcast

data = statcast('2023-04-23', '2023-04-23')

plot_strike_zone(data.loc[data["batter"] == 669016], title = "Brandon Marsh's Three True Outcome Day", colorby='pitcher', annotation="description")
# Out:
# This is a large query, it may take a moment to complete
#   0%|          | 0/1 [00:00<?, ?it/s]C:\Users\knich\Desktop\Data Analytics\Baseball\baseball-analytics-python\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 1/1 [00:03<00:00,  3.91s/it]
# <Axes: title={'center': "Brandon Marsh's Three True Outcome Day"}>

# %%
from pybaseball import playerid_lookup
playerid_lookup('blackmon', 'charlie')

# %%
data = statcast('2024-05-04', '2024-05-04')

plot_strike_zone(data.loc[data["batter"] == 453568], title = "Charlie Blackmon", colorby='pitcher', annotation="description")
# Out:
# This is a large query, it may take a moment to complete
#   0%|          | 0/1 [00:00<?, ?it/s]C:\Users\knich\Desktop\Data Analytics\Baseball\baseball-analytics-python\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
# <Axes: title={'center': 'Charlie Blackmon'}>

# %%
from pybaseball import statcast_batter_exitvelo_barrels

# get data for batters with a minimum of 100 batted ball events in 2019
data = statcast_batter_exitvelo_barrels(2024, 100)

# %%
data.head()
# Out:
#   last_name, first_name  player_id  attempts  avg_hit_angle  \
# 0          Arraez, Luis     650333       218           12.1
# 1         Betts, Mookie     605141       198           19.9
# 2        Semien, Marcus     543760       197           17.2
# 3         Ramírez, José     608070       192           20.2
# 4        Garcia, Maikel     672580       188            7.1
#
#    anglesweetspotpercent  max_hit_speed  avg_hit_speed   ev50  fbld    gb  \
# 0                   45.0          108.4           85.8   94.4  88.1  83.7
# 1                   43.9          109.4           90.8   99.3  91.9  90.4
# 2                   37.1          112.1           87.2   97.5  91.4  82.7
# 3                   34.9          109.0           89.6   99.2  92.7  87.5
# 4                   36.7          108.6           90.9  100.4  93.8  89.7
#
#    max_distance  avg_distance  avg_hr_distance  ev95plus  ev95percent  \
# 0           378           157            374.0        46         21.1
# ...

# %%
data
# Out:
#     last_name, first_name  player_id  attempts  avg_hit_angle  \
# 0            Arraez, Luis     650333       218           12.1
# 1           Betts, Mookie     605141       198           19.9
# 2          Semien, Marcus     543760       197           17.2
# 3           Ramírez, José     608070       192           20.2
# 4          Garcia, Maikel     672580       188            7.1
# ..                    ...        ...       ...            ...
# 195         Hoskins, Rhys     656555       101           19.0
# 196           Kepler, Max     596146       100           17.8
# 197           Pages, Andy     681624       100           23.9
# 198       Kirilloff, Alex     666135       100           12.9
# 199      Schneider, Davis     676914       100           22.2
#
#      anglesweetspotpercent  max_hit_speed  avg_hit_speed   ev50  fbld    gb  \
# 0                     45.0          108.4           85.8   94.4  88.1  83.7
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter('avg_hit_angle', 'avg_distance', data=data)

# %%
plt.scatter('avg_hit_speed', 'avg_distance', data=data)

# %%
from pybaseball import statcast_single_game

# get statcast data for game_pk 
data = statcast_single_game(529429)
# Out:
# C:\Users\knich\Desktop\Data Analytics\Baseball\baseball-analytics-python\env\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)

# %%
data.events.unique()
# Out:
# array(['field_out', 'strikeout', nan, 'field_error', 'home_run',
#        'grounded_into_double_play', 'single', 'sac_bunt'], dtype=object)

# %%
data.description.unique()
# Out:
# array(['hit_into_play', 'called_strike', 'foul', 'ball',
#        'swinging_strike', 'swinging_strike_blocked', 'blocked_ball'],
#       dtype=object)

# %%
data[(data['description'] == 'hit_into_play') & (data['pitcher'] == 445276)]
# Out:
#     pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 171         FC 2018-03-30           88.9          -2.02           6.40
# 187         FC 2018-03-30           87.9          -1.90           6.34
# 192         SL 2018-03-30           79.4          -1.73           6.24
# 220         FC 2018-03-30           89.6          -1.91           6.36
#
#            player_name  batter  pitcher       events    description  ...  \
# 171     Longoria, Evan  446334   445276    field_out  hit_into_play  ...
# 187      Posey, Buster  457763   445276    field_out  hit_into_play  ...
# 192  McCutchen, Andrew  457705   445276  field_error  hit_into_play  ...
# 220         Panik, Joe  605412   445276     home_run  hit_into_play  ...
#
#      post_home_score  post_bat_score  post_fld_score  if_fielding_alignment  \
# 171                0               1               0               Standard
# 187                0               1               0               Standard
# ...

# %%
print(data.columns.tolist())
# Out:
# ['pitch_type', 'game_date', 'release_speed', 'release_pos_x', 'release_pos_z', 'player_name', 'batter', 'pitcher', 'events', 'description', 'spin_dir', 'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des', 'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type', 'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y', 'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot', 'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed', 'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1', 'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 'fielder_9', 'release_pos_y', 'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value'
# ...

# %%
from pybaseball import spraychart

sub_data = data[(data['description'] == 'hit_into_play') & (data['inning_topbot'] == 'Top')]

spraychart(sub_data, 'dodgers', title='SF Giants Spray Chart May 30, 2018')
# Out:
# <Axes: title={'center': 'SF Giants Spray Chart May 30, 2018'}>

# %%
data.inning_topbot
# Out:
# 159    Bot
# 162    Bot
# 163    Bot
# 169    Bot
# 172    Bot
#       ...
# 204    Top
# 208    Top
# 212    Top
# 217    Top
# 224    Top
# Name: inning_topbot, Length: 226, dtype: object

# %%
from pybaseball.plotting import plot_strike_zone

plot_strike_zone(data, title = "Dylan Cease's 1-hitter on Sept 3, 2022")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 from pybaseball.plotting import plot_strike_zone
# ----> 3 plot_strike_zone(data, title = "Dylan Cease's 1-hitter on Sept 3, 2022")
#
# File ~\Desktop\Data Analytics\Baseball\baseball-analytics-python\env\Lib\site-packages\pybaseball\plotting.py:267, in plot_strike_zone(data, title, colorby, legend_title, annotation, axis)
#     261 for color in sub_data[color_label].unique():
#     262     color_sub_data = sub_data[sub_data[color_label] == color]
#     263     scatters.append(axis.scatter(
#     264         color_sub_data["plate_x"],
#     265         color_sub_data['plate_z'],
#     266         s = 10**2,
# --> 267         label = pitch_code_to_name_map[color] if color_label == 'pitch_type' else color,
#     268         alpha = alpha_markers
#     269     ))
# ...

# %%
from pybaseball import statcast_pitcher

pitcher_data = statcast_pitcher('2022-09-03', '2022-09-03', 656302)
# Out:
# Gathering Player Data

# %%
print(pitcher_data.columns.tolist())
# Out:
# ['pitch_type', 'game_date', 'release_speed', 'release_pos_x', 'release_pos_z', 'player_name', 'batter', 'pitcher', 'events', 'description', 'spin_dir', 'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des', 'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type', 'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y', 'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot', 'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed', 'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1', 'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 'fielder_9', 'release_pos_y', 'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value'
# ...

# %%
plot_strike_zone(pitcher_data, title = "Dylan Cease's 1-hitter on Sept 3, 2022")
# Out:
# <Axes: title={'center': "Dylan Cease's 1-hitter on Sept 3, 2022"}>

# %%
pitcher_data
# Out:
#     pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0           SL  2022-09-03           90.2          -1.73           6.03
# 1           KC  2022-09-03           82.9          -1.42           6.18
# 2           FF  2022-09-03           97.7          -1.30           6.36
# 3           SL  2022-09-03           89.2          -1.58           6.21
# 4           SL  2022-09-03           89.3          -1.79           5.93
# ..         ...         ...            ...            ...            ...
# 98          SL  2022-09-03           87.3          -1.69           6.13
# 99          FF  2022-09-03           96.0          -1.25           6.33
# 100         SL  2022-09-03           85.3          -1.58           6.17
# 101         FF  2022-09-03           95.4          -1.48           6.32
# 102         FF  2022-09-03           94.7          -1.34           6.27
#
#       player_name  batter  pitcher     events      description  ...  \
# ...

# %%
data.pitch_type.unique()
# Out:
# array(['CH', 'SL', 'FF', 'FC', 'SI', nan, 'KC'], dtype=object)

# %%
data[data['pitch_type'].isnull()]
data_remove_nan = data.drop([215])

# %%
data_remove_nan.pitch_type.unique()
# Out:
# array(['CH', 'SL', 'FF', 'FC', 'SI', 'KC'], dtype=object)

# %%
plot_strike_zone(data_remove_nan[data_remove_nan['inning_topbot'] == 'Top'], title = "Strike Zone")
# Out:
# <Axes: title={'center': 'Strike Zone'}>
